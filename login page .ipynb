# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'em.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import*


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(831, 407)
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(370, 10, 81, 41))
        self.label.setStyleSheet("color: rgb(255, 0, 0);\n"
"background-color: rgb(255, 255, 255);\n"
"selection-background-color: rgb(255, 255, 255);\n"
"font: 14pt \"OCR A Extended\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(140, 65, 121, 31))
        self.label_2.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 255, 255);\n"
"font: 12pt \"Niagara Solid\";\n"
"font: 75 12pt \"Myanmar Text\";")
        self.label_2.setObjectName("label_2")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(140, 120, 121, 31))
        self.label_5.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 255, 255);\n"
"font: 12pt \"Niagara Solid\";\n"
"font: 75 12pt \"Myanmar Text\";")
        self.label_5.setObjectName("label_5")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(140, 180, 171, 31))
        self.label_3.setStyleSheet("color: rgb(0, 0, 0);\n"
"background-color: rgb(255, 255, 255);\n"
"font: 12pt \"Niagara Solid\";\n"
"font: 75 12pt \"Myanmar Text\";")
        self.label_3.setObjectName("label_3")
        self.fname = QtWidgets.QLineEdit(Form)
        self.fname.setGeometry(QtCore.QRect(280, 70, 171, 22))
        self.fname.setObjectName("fname")
        self.lname = QtWidgets.QLineEdit(Form)
        self.lname.setGeometry(QtCore.QRect(280, 120, 181, 22))
        self.lname.setObjectName("lname")
        self.fnum = QtWidgets.QLineEdit(Form)
        self.fnum.setGeometry(QtCore.QRect(330, 180, 161, 21))
        self.fnum.setObjectName("fnum")
        self.button = QtWidgets.QPushButton(Form)
        self.button.setGeometry(QtCore.QRect(350, 250, 131, 28))
        self.button.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 14pt \"MS Sans Serif\";")
        self.button.setObjectName("button")
        self.button.clicked.connect(self.mail)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
    def mail(self):
        fn=self.fname.text()
        ln=self.lname.text()
        fv=self.fnum.text()
        if len(fn)<1:
            QMessageBox.information(None,"Incomplte Data"," plzz give username ")
        elif len(ln)<1:
            QMessageBox.information(None,"Incomplte Data","plzz give lastname ")
        elif len(fv)<1:
            QMessageBox.information(None,"Incomplte Data","plzz enter the number ")
        else:
            fname=["u1","u2","u3","u4"]
            lname=["l1","l2","l3","l4"]
            fnum=["0","1","2","3"]
            if fn in fname:
                i=fname.index(fn)
                if ln in lname:
                    i=lname.index(ln)
                    if fv ==fnum[i]:
                        self.fname.clear()
                        self.lname.clear()
                        self.fnum.clear()
                        QMessageBox.information(None,"Sucessfully Logged In","username,lastname and password is correct")
                    else:   
                        QMessageBox.information(None,"invalid login","username,lastname and password is inncorrect")
            else:
                QMessageBox.information(None,"unSucessfully Logged In","user not registerd")
            
        
        
        
        

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "LOGIN "))
        self.label_2.setText(_translate("Form", "FIRST NAME :"))
        self.label_5.setText(_translate("Form", "LAST NAME :"))
        self.label_3.setText(_translate("Form", "FAVOURITE NUM :"))
        self.button.setText(_translate("Form", "SUBMIT :"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
